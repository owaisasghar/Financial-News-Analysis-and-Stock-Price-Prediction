# %% [markdown]
# # Candidate Evaluation Assessment Report

# %% [markdown]
# This notebook runs all the scripts in one place.

# %% [markdown]
# # Task 1: Title of the Task 1

# %%
# Please install nbformat before running this script
# pip install nbformat
# %run "Task1_Analysis.ipynb"
# Out:
# [nltk_data] Downloading package punkt to /home/uwais/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/uwais/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/uwais/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/uwais/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/uwais/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# === Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32770 entries, 0 to 32769
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Headlines    32770 non-null  object
# ...

# %% [markdown]
# # Task 2: Stock Ticker Extraction

# %%
# %run "Task2_Stock_Extraction.ipynb"
# Out:
# Total stock mentions found: 8323
# Unique stocks mentioned: 445
# Sample of stock mentions:
#         Date Ticker                                           Headline  \
# 0 2020-07-18  BDNCE  TikTok considers London and other locations fo...
# 1 2020-07-18    DIS  Disney cuts ad spending on Facebook amid growi...
# 2 2020-07-18   META  Disney cuts ad spending on Facebook amid growi...
# 3 2020-07-18  WRCDF  Trail of missing Wirecard executive leads to B...
# 4 2020-07-18   TWTR  Twitter says attackers downloaded data from up...
#
#                                          Description
# 0  TikTok has been in discussions with the UK gov...
# 1  Walt Disney  has become the latest company to ...
# 2  Walt Disney  has become the latest company to ...
# 3  Former Wirecard  chief operating officer Jan M...
# 4  Twitter Inc said on Saturday that hackers were...
# Stock mentions saved to 'stock_mentions.csv'

# %% [markdown]
# # Task 3: Financial Data Analysis

# %%
# %run "Task3_Financial_Analysis.ipynb"
# Out:
# Financial Metrics for AAPL
#
# Basic Info:
# Company Name: Apple Inc.
# Sector: Technology
# Industry: Consumer Electronics
#
# Market Data:
# Market Cap: $3458.40B
# Current Price: 222.64
# Volume: 97333260
# 52 Week High: 260.1
# 52 Week Low: 164.08
#
# Valuation Metrics:
# P/E Ratio: 37.863945
# Forward P/E: 26.903835
# PEG Ratio: N/A
# Price to Book: 59.102734
# Enterprise Value: 3419274739712
#
# Financial Metrics:
# Revenue: 391034994688
# Profit Margin: 23.97%
# Operating Margin: 31.17%
# Return on Equity: 1.5741299
# Quarterly Growth: N/A
#
# Trading Info:
# Beta: 1.24
# Short Ratio: 3.37
# Dividend Yield: 0.43%
# Average Volume: 46183579
# Return Metrics:
#
# Return Metrics:
# Daily Average Return: 0.07%
# Daily Std Dev: 1.45%
# Annualized Return: 17.06%
# Annualized Volatility: 23.02%
# Total Return: 15.39%
# Sharpe Ratio: 0.74
# Max Drawdown: -15.35%
#
# Peer Comparison:
#   Ticker Market Cap  P/E Ratio Profit Margin    Beta
# ...

# %% [markdown]
# # Task 04: Stock Price Prediction

# %%
# %run "Task4-TimeSeries_Forecasting.ipynb"

# %% [markdown]
# # Task 5: News Analysis and Impact Evaluation

# %%
# %run "Task5_News_Impact.ipynb"
# Out:
# Total news articles: 8323
#
# Top mentioned stocks:
# Ticker
# BA      1242
# META     754
# AAPL     741
# TSLA     699
# AMZN     668
# Name: count, dtype: int64
# Analysis Results for BA:
# - Weak positive correlation (0.04) between news sentiment and stock movement
# - Most discussed topic: management (170 articles)
# - Most positive topic: company_events (sentiment: 0.05)
# - Most positive news sentiment occurs on Saturday
# - Found 23 days with unusually high news volume
#                    topic  article_count  avg_sentiment
# 4             management            170       0.049894
# 1       market_sentiment             68       0.042259
# 0  financial_performance             66       0.004135
# 2         company_events             42       0.051581
# 3             regulatory             19      -0.036842
# Confidence Assessment:
# - Overall confidence: 0.62
# - Sample size confidence: 1.00
# - Relationship consistency: 0.83
#
# Recommendations:
# ...
